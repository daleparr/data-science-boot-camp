# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import pi

# Load the CSV files
innovation_efficiency_df = pd.read_csv('innovation_efficiency.csv')
cultural_resonance_df = pd.read_csv('cultural_resonace.csv')
resource_utilization_df = pd.read_csv('resource_utilization.csv')

# %%
innovation_efficiency_df.boxplot()
plt.show()

# %%
cultural_resonance_df.boxplot()
plt.show()

# %%
resource_utilization_df.boxplot()
plt.show()
